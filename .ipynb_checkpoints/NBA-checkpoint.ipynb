# %%
import nba_py
import pandas as pd

from nba_py import game, player
from nba_py.player import PlayerList, PlayerCareer

# %%
# Get every player from 2000-2001 to 2016-2017

players2000 = PlayerList(season='2000-01').info()
players2001 = PlayerList(season='2001-02').info()
players2002 = PlayerList(season='2002-03').info()
players2003 = PlayerList(season='2003-04').info()
players2004 = PlayerList(season='2004-05').info()
players2005 = PlayerList(season='2005-06').info()
players2006 = PlayerList(season='2006-07').info()
players2007 = PlayerList(season='2007-08').info()
players2008 = PlayerList(season='2008-09').info()
players2009 = PlayerList(season='2009-10').info()
players2010 = PlayerList(season='2010-11').info()
players2011 = PlayerList(season='2011-12').info()
players2012 = PlayerList(season='2012-13').info()
players2013 = PlayerList(season='2013-14').info()
players2014 = PlayerList(season='2014-15').info()
players2015 = PlayerList(season='2015-16').info()
players2016 = PlayerList(season='2016-17').info()

# %%
list2000 = players2000['PERSON_ID'].tolist()
list2001 = players2001['PERSON_ID'].tolist()
list2002 = players2002['PERSON_ID'].tolist()
list2003 = players2003['PERSON_ID'].tolist()
list2004 = players2004['PERSON_ID'].tolist()
list2005 = players2005['PERSON_ID'].tolist()
list2006 = players2006['PERSON_ID'].tolist()
list2007 = players2007['PERSON_ID'].tolist()
list2008 = players2008['PERSON_ID'].tolist()
list2009 = players2009['PERSON_ID'].tolist()
list2010 = players2010['PERSON_ID'].tolist()
list2011 = players2011['PERSON_ID'].tolist()
list2012 = players2012['PERSON_ID'].tolist()
list2013 = players2013['PERSON_ID'].tolist()
list2014 = players2014['PERSON_ID'].tolist()
list2015 = players2015['PERSON_ID'].tolist()
list2016 = players2016['PERSON_ID'].tolist()

# %%
# Iterate through every player
ids = []
points = []
rebounds = []
assists = []
blocks = []
steals = []
turnovers = []
num_games = []
minutes_played = []

# %%
# Append year 2000
for n in list2000:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    

df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2001
for n in list2001:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2002
for n in list2002:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2003
for n in list2003:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2004
for n in list2004:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2005
for n in list2005:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2006
for n in list2006:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2007
for n in list2007:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2008
for n in list2008:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2009
for n in list2009:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2010
for n in list2010:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2011
for n in list2011:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2012
for n in list2012:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2013
for n in list2013:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2014
for n in list2014:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2015
for n in list2015:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
# Append year 2016
for n in list2016:
    player_totals = player.PlayerCareer(n)
    player_summary = player.PlayerSummary(n)
    ids.append(player_summary.info().FIRST_NAME + ' ' + player_summary.info().LAST_NAME)
    rebounds.append(player_totals.regular_season_totals().REB)
    points.append(player_totals.regular_season_totals().PTS)
    assists.append(player_totals.regular_season_totals().AST)
    blocks.append(player_totals.regular_season_totals().BLK)
    steals.append(player_totals.regular_season_totals().STL)
    turnovers.append(player_totals.regular_season_totals().TOV)
    num_games.append(player_totals.regular_season_totals().GP)
    minutes_played.append(player_totals.regular_season_totals().MIN)    
df = pd.DataFrame({'Name': ids, 'Total Points': points, 'Total Rebounds': rebounds,
                   'Total Assists': assists, 'Total Blocks': blocks,
                   'Total Steals': steals, 'Total Turnovers': turnovers,
                   '# Games Played': num_games, "Minutes Played": minutes_played})

# %%
del points, rebounds, assists, blocks, steals, turnovers, num_games, minutes_played

# %%
df = df[['Name', 'Total Points', 'Total Rebounds', 'Total Assists', 'Total Blocks', 'Total Steals', 'Total Turnovers', '# Games Played', 'Minutes Played']]
df
# Out:
#                                        Name  \
# 0     0    Mahmoud Abdul-Rauf
# dtype: object
# 1             0    Ike Austin
# dtype: object
# 2         0    Corey Benjamin
# dtype: object
# 3           0    David Benoit
# dtype: object
# 4        0    Mookie Blaylock
# dtype: object
# 5          0    Muggsy Bogues
# dtype: object
# 6       0    Etdrick Bohannon
# dtype: object
# 7              0    Dee Brown
# dtype: object
# 8           0    Matt Bullard
# dtype: object
# 9          0    Scott Burrell
# dtype: object
# 10            0    Chris Carr
# dtype: object
# 11        0    Duane Causwell
# dtype: object
# 12       0    Cedric Ceballos
# dtype: object
# 13           0    Keith Closs
# dtype: object
# 14            0    John Coker
# dtype: object
# 15           0    Sean Colson
# dtype: object
# 16         0    Tyrone Corbin
# dtype: object
# 17           0    John Crotty
# dtype: object
# 18           0    Bill Curley
# dtype: object
# 19          0    Kornel David
# ...
